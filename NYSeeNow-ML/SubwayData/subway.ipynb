# %% [markdown]
# ### This notebook will be for processing and cleaning the subway turnstile dataset for 2019
# - Will need to determine all the turnstile differences for entries between current and last value
# - Same for exits
# - This can give me a representation of how many people enter/exit station X in a given time period
# - Do this for only stations in Manhattan

# %%
import json
import pandas as pd

# %% [markdown]
# ### Explanation of linking the 3 datasets to get useful information:
# - turnstile_data is the dataset obtained from: https://data.ny.gov/Transportation/Turnstile-Usage-Data-2019/xfn5-qji9
# - This dataset contains all the info in 2019 for all the turnstiles in the MTA system
# - station_data is a dataset obtained from: http://web.mta.info/developers/data/nyct/subway/Stations.csv
# - This dataset contains information for all the stations in the MTA system
# - The problem that occurs is how to link the two datasets together
# - lookup_data

# %%
turnstile_data = pd.read_csv('Turnstile_Usage_Data__2019.csv')
turnstile_data.head()
# Out:
#     C/A  Unit       SCP         Station Line Name Division        Date  \
# 0  A033  R170  02-00-05  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 1  A033  R170  02-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 2  A033  R170  02-06-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 3  A033  R170  02-00-03  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 4  A033  R170  02-06-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
#
#        Time Description   Entries  \
# 0  00:00:00     REGULAR  17538854
# 1  00:00:00     REGULAR  14983900
# 2  00:00:00     REGULAR    769115
# 3  00:00:00     REGULAR   7191422
# 4  00:00:00     REGULAR  71047673
#
#    Exits
# 0                                            7031168
# 1                                           14554087
# 2                                             559221
# 3                                            8417203
# 4                                           20925389

# %%
with open('stations.csv') as file:
    station_data = pd.read_csv(file)
station_data.head()
# Out:
#    ogc_fid  station id complex id gtfs stop id division     line  \
# 0        1         1.0          1          R01      BMT  Astoria
# 1        2         2.0          2          R03      BMT  Astoria
# 2        3         3.0          3          R04      BMT  Astoria
# 3        4         4.0          4          R05      BMT  Astoria
# 4        5         5.0          5          R06      BMT  Astoria
#
#                 stop name borough daytime routes structure  gtfs latitude  \
# 0  Astoria - Ditmars Blvd       Q            N W  Elevated      40.775036
# 1            Astoria Blvd       Q            N W  Elevated      40.770258
# 2                   30 Av       Q            N W  Elevated      40.766779
# 3                Broadway       Q            N W  Elevated      40.761820
# 4                   36 Av       Q            N W  Elevated      40.756804
#
#    gtfs longitude   north direction label south direction label
# 0      -73.912034                     NaN             Manhattan
# 1      -73.917843            Ditmars Blvd             Manhattan
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan

# %%
with open('remote_complex_lookup.csv') as file:
    lookup_data = pd.read_csv(file)
lookup_data.head()
# Out:
#   remote   booth  complex_id       station line_name division
# 0    R001   A060       635.0  WHITEHALL ST        R1      BMT
# 1    R001   A058       635.0  WHITEHALL ST        R1      BMT
# 2    R001  R101S       635.0   SOUTH FERRY        R1      IRT
# 3    R002   A077       628.0     FULTON ST  ACJZ2345      BMT
# 4    R002   A081       628.0     FULTON ST  ACJZ2345      BMT

# %%
#count the number of null values for complex id
lookup_data['complex_id'].isnull().sum()
# Out:
# 0

# %%
#change the complex id column to object instead of float
lookup_data['complex_id'] = lookup_data['complex_id'].astype(str)
lookup_data.head()
# Out:
#   remote   booth complex_id       station line_name division
# 0    R001   A060      635.0  WHITEHALL ST        R1      BMT
# 1    R001   A058      635.0  WHITEHALL ST        R1      BMT
# 2    R001  R101S      635.0   SOUTH FERRY        R1      IRT
# 3    R002   A077      628.0     FULTON ST  ACJZ2345      BMT
# 4    R002   A081      628.0     FULTON ST  ACJZ2345      BMT

# %% [markdown]
# ### First lets look at all the station_data dataset
# - First I will drop all rows that are not in Manhattan

# %%
for i in range(len(station_data)):
    if station_data['borough'][i] == 'Q' or  station_data['borough'][i] == 'Bk' or station_data['borough'][i] == 'Bx'or station_data['borough'][i] == 'SI':
        station_data.drop(i, inplace=True)

station_data.head()
# Out:
#     ogc_fid  station id complex id gtfs stop id division                 line  \
# 6         7         7.0        613          R11      BMT              Astoria
# 7         8         8.0          8          R13      BMT              Astoria
# 8         9         9.0          9          R14      BMT  Broadway - Brighton
# 9        10        10.0         10          R15      BMT  Broadway - Brighton
# 10       11        11.0        611          R16      BMT  Broadway - Brighton
#
#              stop name borough daytime routes structure  gtfs latitude  \
# 6   Lexington Av/59 St       M          N W R    Subway      40.762660
# 7           5 Av/59 St       M          N W R    Subway      40.764811
# 8         57 St - 7 Av       M        N Q R W    Subway      40.764664
# 9                49 St       M          N R W    Subway      40.759901
# 10    Times Sq - 42 St       M        N Q R W    Subway      40.754672
#
#     gtfs longitude north direction label south direction label
# 6       -73.967258                Queens   Downtown & Brooklyn
# 7       -73.973347                Queens   Downtown & Brooklyn
# 8       -73.980658       Uptown & Queens   Downtown & Brooklyn
# 9       -73.984139       Uptown & Queens   Downtown & Brooklyn
# 10      -73.986754       Uptown & Queens   Downtown & Brooklyn

# %%
station_data.tail(20)
# Out:
#      ogc_fid  station id complex id gtfs stop id division       line  \
# 472      473       475.0        475          Q05      IND  Second Av
# 473      474       476.0        476          Q04      IND  Second Av
# 474      475       477.0        477          Q03      IND  Second Av
# 496      497         NaN       R468          NaN      RIT        NaN
# 497      498         NaN       R469          NaN      RIT        NaN
# 498      499         NaN       R540          NaN      PTH        NaN
# 499      500         NaN       R541          NaN      PTH        NaN
# 500      501         NaN       R542          NaN      PTH        NaN
# 501      502         NaN       R543          NaN      PTH        NaN
# 502      503         NaN       R544          NaN      PTH        NaN
# 503      504         NaN       R545          NaN      PTH        NaN
# 504      505         NaN       R546          NaN      PTH        NaN
# 505      506         NaN       R547          NaN      PTH        NaN
# 506      507         NaN       R548          NaN      PTH        NaN
# 507      508         NaN       R549          NaN      PTH        NaN
# 508      509         NaN       R550          NaN      PTH        NaN
# 509      510         NaN       R551          NaN      PTH        NaN
# 510      511         NaN       R552          NaN      PTH        NaN
# 511      512         NaN       R535          NaN      JFK        NaN
# 512      513         NaN       R536          NaN      JFK        NaN
#
#                              stop name borough daytime routes structure  \
# 472                              96 St       M              Q    Subway
# 473                              86 St       M              Q    Subway
# 474                              72 St       M              Q    Subway
# 496  Roosevelt Island Tram - Eastbound     NaN            NaN       NaN
# 497  Roosevelt Island Tram - Westbound     NaN            NaN       NaN
# 498                 World Trade Center     NaN            NaN       NaN
# 499                              33 St     NaN            NaN       NaN
# 500                              23 St     NaN            NaN       NaN
# 501                        Exchange Pl     NaN            NaN       NaN
# 502                           Harrison     NaN            NaN       NaN
# 503                              14 St     NaN            NaN       NaN
# 504                    Pavonia/Newport     NaN            NaN       NaN
# 505                               9 St     NaN            NaN       NaN
# 506                     Christopher St     NaN            NaN       NaN
# 507                Newark Penn Station     NaN            NaN       NaN
# 508                            Hoboken     NaN            NaN       NaN
# 509                           Grove St     NaN            NaN       NaN
# 510                         Journal Sq     NaN            NaN       NaN
# 511                       Howard Beach     NaN            NaN       NaN
# 512                            Jamaica     NaN            NaN       NaN
#
#      gtfs latitude  gtfs longitude north direction label south direction label
# 472      40.784318      -73.947152                   NaN   Downtown & Brooklyn
# 473      40.777891      -73.951787                Uptown   Downtown & Brooklyn
# 474      40.768799      -73.958424                Uptown   Downtown & Brooklyn
# 496      40.761186      -73.964191                   NaN                   NaN
# 497      40.757307      -73.954097                   NaN                   NaN
# 498      40.712052      -74.014129                   NaN                   NaN
# 499      40.747850      -73.989875                   NaN                   NaN
# 500      40.742672      -73.994177                   NaN                   NaN
# 501      40.716554      -74.033372                   NaN                   NaN
# 502      40.740472      -74.157344                   NaN                   NaN
# 503      40.738507      -73.998741                   NaN                   NaN
# 504      40.725005      -74.038257                   NaN                   NaN
# 505      40.734409      -74.000463                   NaN                   NaN
# 506      40.732593      -74.008924                   NaN                   NaN
# 507      40.733585      -74.167920                   NaN                   NaN
# 508      40.734910      -74.033220                   NaN                   NaN
# 509      40.723621      -74.044832                   NaN                   NaN
# 510      40.730304      -74.068633                   NaN                   NaN
# 511      40.661051      -73.829638                   NaN                   NaN
# 512      40.698942      -73.808416                   NaN                   NaN

# %%
#take out the last 17 station names and put them in a list
station_names = station_data['stop name'].tail(17).tolist()
station_names
# Out:
# ['Roosevelt Island Tram - Eastbound',
#  'Roosevelt Island Tram - Westbound',
#  'World Trade Center',
#  '33 St',
#  '23 St',
#  'Exchange Pl',
#  'Harrison',
#  '14 St',
#  'Pavonia/Newport',
#  '9 St',
#  'Christopher St',
#  'Newark Penn Station',
#  'Hoboken',
#  'Grove St',
#  'Journal Sq',
#  'Howard Beach',
#  'Jamaica']

# %%
station_names_to_drop=['Roosevelt Island Tram - Eastbound',
 'Roosevelt Island Tram - Westbound',
 'Exchange Pl',
 'Harrison',
 'Pavonia/Newport',
 '9 St',
 'Newark Penn Station',
 'Hoboken',
 'Grove St',
 'Journal Sq',
 'Howard Beach',
 'Jamaica']

 # Create a boolean mask to identify rows with names are in the list
mask = station_data['stop name'].isin(station_names_to_drop)

# Apply the mask to drop the rows
station_data = station_data[~mask]

station_data.tail(10)
# Out:
#      ogc_fid  station id complex id gtfs stop id division  \
# 470      471       469.0        610          901      IRT
# 471      472       471.0        471          726      IRT
# 472      473       475.0        475          Q05      IND
# 473      474       476.0        476          Q04      IND
# 474      475       477.0        477          Q03      IND
# 498      499         NaN       R540          NaN      PTH
# 499      500         NaN       R541          NaN      PTH
# 500      501         NaN       R542          NaN      PTH
# 503      504         NaN       R545          NaN      PTH
# 506      507         NaN       R548          NaN      PTH
#
#                     line              stop name borough daytime routes  \
# 470  Lexington - Shuttle  Grand Central - 42 St       M              S
# 471             Flushing          34 St - 11 Av       M              7
# 472            Second Av                  96 St       M              Q
# 473            Second Av                  86 St       M              Q
# 474            Second Av                  72 St       M              Q
# 498                  NaN     World Trade Center     NaN            NaN
# 499                  NaN                  33 St     NaN            NaN
# 500                  NaN                  23 St     NaN            NaN
# 503                  NaN                  14 St     NaN            NaN
# 506                  NaN         Christopher St     NaN            NaN
#
#     structure  gtfs latitude  gtfs longitude north direction label  \
# 470    Subway      40.752769      -73.979189              Times Sq
# 471    Subway      40.755882      -74.001910                Queens
# 472    Subway      40.784318      -73.947152                   NaN
# 473    Subway      40.777891      -73.951787                Uptown
# 474    Subway      40.768799      -73.958424                Uptown
# 498       NaN      40.712052      -74.014129                   NaN
# 499       NaN      40.747850      -73.989875                   NaN
# 500       NaN      40.742672      -73.994177                   NaN
# 503       NaN      40.738507      -73.998741                   NaN
# 506       NaN      40.732593      -74.008924                   NaN
#
#     south direction label
# 470                   NaN
# 471                   NaN
# 472   Downtown & Brooklyn
# 473   Downtown & Brooklyn
# 474   Downtown & Brooklyn
# 498                   NaN
# 499                   NaN
# 500                   NaN
# 503                   NaN
# 506                   NaN

# %%
#set the last 5 rows column[gtfs stop id] to the complex id value
station_data.loc[station_data.tail(5).index, 'gtfs stop id'] = station_data['complex id'].tail(5)

# %%
#change complex id in station to have .0 and be of type string
station_data['complex id'] = station_data['complex id'].astype(str)
station_data['complex id'] = station_data['complex id'] + '.0'

# %% [markdown]
# ### Now match up complex_id in station_data with complex_id in lookup_data

# %%
remote_booth_and_station = pd.merge(station_data, lookup_data, left_on='complex id', right_on='complex_id')
remote_booth_and_station.head()
# Out:
#    ogc_fid  station id complex id gtfs stop id division_x     line  \
# 0        7         7.0      613.0          R11        BMT  Astoria
# 1        7         7.0      613.0          R11        BMT  Astoria
# 2        7         7.0      613.0          R11        BMT  Astoria
# 3        7         7.0      613.0          R11        BMT  Astoria
# 4        7         7.0      613.0          R11        BMT  Astoria
#
#             stop name borough daytime routes structure  gtfs latitude  \
# 0  Lexington Av/59 St       M          N W R    Subway       40.76266
# 1  Lexington Av/59 St       M          N W R    Subway       40.76266
# 2  Lexington Av/59 St       M          N W R    Subway       40.76266
# 3  Lexington Av/59 St       M          N W R    Subway       40.76266
# 4  Lexington Av/59 St       M          N W R    Subway       40.76266
#
#    gtfs longitude north direction label south direction label remote   booth  \
# 0      -73.967258                Queens   Downtown & Brooklyn    R016  N305A
# 1      -73.967258                Queens   Downtown & Brooklyn    R017   N306
# 2      -73.967258                Queens   Downtown & Brooklyn    R017   N305
# 3      -73.967258                Queens   Downtown & Brooklyn    R050   R244
# 4      -73.967258                Queens   Downtown & Brooklyn    R050  R244A
#
#   complex_id          station line_name division_y
# 0      613.0  LEXINGTON-53 ST       EM6        IND
# 1      613.0  LEXINGTON-53 ST       EM6        IND
# 2      613.0  LEXINGTON-53 ST       EM6        IND
# 3      613.0            59 ST    456NQR        IRT
# 4      613.0            59 ST    456NQR        IRT

# %%
#drop the following columns: ogc_fid, gtfs stop id, division_x, line, daytime routes, structure, north direction label, south direction label, line_name, division_y
remote_booth_and_station.drop(['ogc_fid', 'complex id','gtfs stop id', 'division_x', 'line', 'daytime routes', 'structure', 'north direction label', 'south direction label', 'line_name', 'division_y'], axis=1, inplace=True)

remote_booth_and_station.head()
# Out:
#    station id           stop name borough  gtfs latitude  gtfs longitude  \
# 0         7.0  Lexington Av/59 St       M       40.76266      -73.967258
# 1         7.0  Lexington Av/59 St       M       40.76266      -73.967258
# 2         7.0  Lexington Av/59 St       M       40.76266      -73.967258
# 3         7.0  Lexington Av/59 St       M       40.76266      -73.967258
# 4         7.0  Lexington Av/59 St       M       40.76266      -73.967258
#
#   remote   booth complex_id          station
# 0    R016  N305A      613.0  LEXINGTON-53 ST
# 1    R017   N306      613.0  LEXINGTON-53 ST
# 2    R017   N305      613.0  LEXINGTON-53 ST
# 3    R050   R244      613.0            59 ST
# 4    R050  R244A      613.0            59 ST

# %%
remote_booth_and_station.head(50)
# Out:
#     station id           stop name borough  gtfs latitude  gtfs longitude  \
# 0          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 1          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 2          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 3          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 4          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 5          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 6          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 7          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 8          7.0  Lexington Av/59 St       M      40.762660      -73.967258
# 9        400.0               59 St       M      40.762526      -73.967967
# 10       400.0               59 St       M      40.762526      -73.967967
# 11       400.0               59 St       M      40.762526      -73.967967
# 12       400.0               59 St       M      40.762526      -73.967967
# 13       400.0               59 St       M      40.762526      -73.967967
# 14       400.0               59 St       M      40.762526      -73.967967
# 15       400.0               59 St       M      40.762526      -73.967967
# 16       400.0               59 St       M      40.762526      -73.967967
# 17       400.0               59 St       M      40.762526      -73.967967
# 18         8.0          5 Av/59 St       M      40.764811      -73.973347
# 19         8.0          5 Av/59 St       M      40.764811      -73.973347
# 20         9.0        57 St - 7 Av       M      40.764664      -73.980658
# 21         9.0        57 St - 7 Av       M      40.764664      -73.980658
# 22        10.0               49 St       M      40.759901      -73.984139
# 23        10.0               49 St       M      40.759901      -73.984139
# 24        10.0               49 St       M      40.759901      -73.984139
# 25        10.0               49 St       M      40.759901      -73.984139
# 26        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 27        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 28        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 29        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 30        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 31        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 32        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 33        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 34        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 35        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 36        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 37        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 38        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 39        11.0    Times Sq - 42 St       M      40.754672      -73.986754
# 40       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 41       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 42       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 43       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 44       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 45       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 46       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 47       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 48       317.0    Times Sq - 42 St       M      40.755290      -73.987495
# 49       317.0    Times Sq - 42 St       M      40.755290      -73.987495
#
#    remote   booth complex_id          station
# 0     R016  N305A      613.0  LEXINGTON-53 ST
# 1     R017   N306      613.0  LEXINGTON-53 ST
# 2     R017   N305      613.0  LEXINGTON-53 ST
# 3     R050   R244      613.0            59 ST
# 4     R050  R244A      613.0            59 ST
# 5     R050   A004      613.0    LEXINGTON AVE
# 6     R051   R245      613.0            59 ST
# 7     R051  R245A      613.0            59 ST
# 8     R051   A002      613.0    LEXINGTON AVE
# 9     R016  N305A      613.0  LEXINGTON-53 ST
# 10    R017   N306      613.0  LEXINGTON-53 ST
# 11    R017   N305      613.0  LEXINGTON-53 ST
# 12    R050   R244      613.0            59 ST
# 13    R050  R244A      613.0            59 ST
# 14    R050   A004      613.0    LEXINGTON AVE
# 15    R051   R245      613.0            59 ST
# 16    R051  R245A      613.0            59 ST
# 17    R051   A002      613.0    LEXINGTON AVE
# 18    R079   A006        8.0      5 AVE-59 ST
# 19    R079   A007        8.0      5 AVE-59 ST
# 20    R080   A010        9.0      57 ST-7 AVE
# 21    R080   A011        9.0      57 ST-7 AVE
# 22    R081   A015       10.0      49 ST-7 AVE
# 23    R081   A013       10.0      49 ST-7 AVE
# 24    R081   A014       10.0      49 ST-7 AVE
# 25    R081   A016       10.0      49 ST-7 AVE
# 26    R010  N062A      611.0  42 ST-PA BUS TE
# 27    R010   N060      611.0  42 ST-PA BUS TE
# 28    R011  N063A      611.0  42 ST-PA BUS TE
# 29    R011   N062      611.0  42 ST-PA BUS TE
# 30    R011   N063      611.0  42 ST-PA BUS TE
# 31    R032   R145      611.0   42 ST-TIMES SQ
# 32    R032   A021      611.0   42 ST-TIMES SQ
# 33    R032   R143      611.0   42 ST-TIMES SQ
# 34    R032   R146      611.0   42 ST-TIMES SQ
# 35    R033   R151      611.0   42 ST-TIMES SQ
# 36    R033   R148      611.0   42 ST-TIMES SQ
# 37    R033   R150      611.0   42 ST-TIMES SQ
# 38    R033   R153      611.0   42 ST-TIMES SQ
# 39    R033   R147      611.0   42 ST-TIMES SQ
# 40    R010  N062A      611.0  42 ST-PA BUS TE
# 41    R010   N060      611.0  42 ST-PA BUS TE
# 42    R011  N063A      611.0  42 ST-PA BUS TE
# 43    R011   N062      611.0  42 ST-PA BUS TE
# 44    R011   N063      611.0  42 ST-PA BUS TE
# 45    R032   R145      611.0   42 ST-TIMES SQ
# 46    R032   A021      611.0   42 ST-TIMES SQ
# 47    R032   R143      611.0   42 ST-TIMES SQ
# 48    R032   R146      611.0   42 ST-TIMES SQ
# 49    R033   R151      611.0   42 ST-TIMES SQ

# %%
len(remote_booth_and_station)
# Out:
# 480

# %% [markdown]
# ### Lets now look at the turnstile_data dataset
# - First I should drop all the rows that concern Manhattan stations only. I can do this ??
# - I will convert date and time to unix timestamp, name: timestamp
# - I will combine C/A, Unit, SCP and the timestamp to create a unique identifier for each row, name: id
# - I will combine C/A, Unit and SCP to create a unique id for each, name: turnstile_id
# - I will calculate the entry and exit values for each row, name: entry_diff and exit_diff

# %% [markdown]
# ### Extract subway names and co-ordinates from overpass turbo json file

# %%
#there are 161 stations in this dataset

# Open the geojson file and read it
with open('manSubTurn.geojson') as file:
    data = json.load(file)


subway=pd.DataFrame(columns=['name','short_name','lat','lon','Link to Turnstile Data'])

for i in range(len(data['features'])):
    #Extract 
    name=data['features'][i]['properties']['name']
    try:
        short_n=data['features'][i]['properties']['short_name']
    except:
        short_n='None'
        
    lat=data['features'][i]['geometry']['coordinates'][1]
    lon=data['features'][i]['geometry']['coordinates'][0]
    subway.loc[i]=[name,short_n,lat,lon,'None']

# %%
subway.tail(20)
# Out:
#                             name             short_name        lat        lon  \
# 142       Grand Central Terminal                   None  40.752806 -73.977179
# 143                  Marble Hill                   None  40.874924 -73.912702
# 144                    Manhattan                   None  41.418606 -87.989013
# 145                  59th Street                  59 St  40.762707 -73.967880
# 146              Chambers Street            Chambers St  40.714916 -74.007968
# 147                Fulton Street              Fulton St  40.710186 -74.007664
# 148                  49th Street                  49 St  40.759901 -73.984139
# 149    34th Street–Herald Square        34 St–Herald Sq  40.749719 -73.987823
# 150                  23rd Street                  23 St  40.742853 -73.992834
# 151                 Union Square               Union Sq  40.734603 -73.990360
# 152     34th Street–Hudson Yards     34 St–Hudson Yards  40.755913 -74.001900
# 153  59th Street–Columbus Circle  59 St–Columbus Circle  40.768381 -73.981916
# 154                   8th Avenue                   8 Av  40.739875 -74.002738
# 155     42nd Street–Times Square         42 St–Times Sq  40.755286 -73.987216
# 156                 Times Square               Times Sq  40.755592 -73.985839
# 157                   6th Avenue                   6 Av  40.737459 -73.997068
# 158                 Canal Street               Canal St  40.718620 -74.000768
# 159                 168th Street                 168 St  40.840508 -73.940226
# 160                Fulton Street              Fulton St  40.710364 -74.009570
# 161                Fulton Street              Fulton St  40.709426 -74.006586
#
#     Link to Turnstile Data
# 142                   None
# 143                   None
# 144                   None
# 145                   None
# 146                   None
# 147                   None
# 148                   None
# 149                   None
# 150                   None
# 151                   None
# 152                   None
# 153                   None
# 154                   None
# 155                   None
# 156                   None
# 157                   None
# 158                   None
# 159                   None
# 160                   None
# 161                   None

# %%
#remove duplicates? depends on how granular the data for 2019 is

# %% [markdown]
# ### Now import the turnstile data for 2019

# %%
with open('Turnstile_Usage_Data__2019.csv') as file:
    turn_data = pd.read_csv(file)

turn_data.head(20)
# Out:
#      C/A  Unit       SCP         Station Line Name Division        Date  \
# 0   A033  R170  02-00-05  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 1   A033  R170  02-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 2   A033  R170  02-06-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 3   A033  R170  02-00-03  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 4   A033  R170  02-06-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 5   A033  R170  02-00-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 6   A033  R170  02-00-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 7   A033  R170  02-00-04  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 8   A034  R170  03-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 9   A034  R170  03-03-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 10  A034  R170  03-05-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 11  A034  R170  03-03-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 12  A034  R170  03-05-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 13  A034  R170  03-03-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 14  A034  R170  03-05-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 15  A034  R170  03-00-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 16  A034  R170  03-05-03  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 17  A034  R170  03-00-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 18  A035  R170  00-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 19  A035  R170  00-00-04  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
#
#         Time Description   Entries  \
# 0   00:00:00     REGULAR  17538854
# 1   00:00:00     REGULAR  14983900
# 2   00:00:00     REGULAR    769115
# 3   00:00:00     REGULAR   7191422
# 4   00:00:00     REGULAR  71047673
# 5   00:00:00     REGULAR   2430093
# 6   00:00:00     REGULAR    271981
# 7   00:00:00     REGULAR   6483080
# 8   00:00:00     REGULAR   4632187
# 9   00:00:00     REGULAR     69926
# 10  00:00:00     REGULAR    187295
# 11  00:00:00     REGULAR  13154638
# 12  00:00:00     REGULAR    169531
# 13  00:00:00     REGULAR   6553678
# 14  00:00:00     REGULAR    198226
# 15  00:00:00     REGULAR   1007426
# 16  00:00:00     REGULAR    226289
# 17  00:00:00     REGULAR   2167998
# 18  00:00:00     REGULAR    993554
# 19  00:00:00     REGULAR   3119391
#
#     Exits
# 0                                             7031168
# 1                                            14554087
# 2                                              559221
# 3                                             8417203
# 4                                            20925389
# 5                                             2921770
# 6                                              828662
# 7                                             4945335
# 8                                             3269462
# 9                                              219187
# 10                                             129140
# 11                                            1446679
# 12                                             203256
# 13                                            3942370
# 14                                             260680
# 15                                            2330092
# 16                                             172333
# 17                                           16966778
# 18                                            2432341
# 19                                             554073

# %%
#find how many unique subway names there are
turn_data['Station'].nunique()
# Out:
# 379

# %% [markdown]
# #### Columns of interest
# - Station, this is the station name which I will compare with Overpass turbo name data to only have manhattan turnstile data
# - Date, needed for determing day of the week and time of year
# - Time, needed for determing time of day
# - Entries, needed for determing how many people entered the station, useful for busyness
# - Exits, needed for determing how many people exited the station, useful for busyness
# - Might also need to include individual turnstile data to see where people are entering/exiting the station and for comparing that turnstile to its previous value to see the difference

# %% [markdown]
# ### Drop the rows that are not in Manhattan
# #### Change overpass turbo names to match turnstile names

# %%
#capitalize all overpass turbo names
subway['name'] = subway['name'].str.upper()
subway['short_name'] = subway['short_name'].str.upper()
subway.head(20)
# Out:
#                              name           short_name        lat        lon  \
# 0                     96TH STREET                96 ST  40.794379 -73.972000
# 1                   BOWLING GREEN                 NONE  40.704509 -74.014095
# 2                     SOUTH FERRY                 NONE  40.701710 -74.013149
# 3                     86TH STREET                86 ST  40.779494 -73.955529
# 4                     28TH STREET                28 ST  40.743314 -73.984075
# 5        14TH STREET–UNION SQUARE       14 ST–UNION SQ  40.735761 -73.990649
# 6                     28TH STREET                28 ST  40.745494 -73.988691
# 7                    CANAL STREET             CANAL ST  40.718092 -73.999892
# 8       BROADWAY–LAFAYETTE STREET   B’WAY–LAFAYETTE ST  40.725297 -73.996204
# 9                      5TH AVENUE                 5 AV  40.753743 -73.981900
# 10      42ND STREET–GRAND CENTRAL  42 ST–GRAND CENTRAL  40.751772 -73.976825
# 11         5TH AVENUE–59TH STREET           5 AV–59 ST  40.764827 -73.972675
# 12            HARLEM–148TH STREET        HARLEM–148 ST  40.823712 -73.936101
# 13  163RD STREET–AMSTERDAM AVENUE  163 ST–AMSTERDAM AV  40.836945 -73.940126
# 14                  RECTOR STREET            RECTOR ST  40.707363 -74.013850
# 15                  WTC CORTLANDT                 NONE  40.711115 -74.012270
# 16                CHAMBERS STREET          CHAMBERS ST  40.715508 -74.009245
# 17                    WALL STREET              WALL ST  40.706724 -74.009183
# 18                  EAST BROADWAY        EAST BROADWAY  40.713715 -73.990173
# 19                   GRAND STREET             GRAND ST  40.718162 -73.993784
#
#    Link to Turnstile Data
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# 5                    None
# 6                    None
# 7                    None
# 8                    None
# 9                    None
# 10                   None
# 11                   None
# 12                   None
# 13                   None
# 14                   None
# 15                   None
# 16                   None
# 17                   None
# 18                   None
# 19                   None

# %%
# Now search for the short name in the turnstile data
# If it is not there, search for the long name

stations_to_extract_from_turnstile = []
change_name_stations_to_extract_from_turnstile = []
for i in range(len(subway)):
    name = subway.iloc[i]['name']
    short_name = subway.iloc[i]['short_name']
    if short_name in turn_data['Station'].values:
        stations_to_extract_from_turnstile.append(short_name)
        subway.loc[i,'Link to Turnstile Data'] = short_name
    elif name in turn_data['Station'].values:
        stations_to_extract_from_turnstile.append(name)
        subway.loc[i,'Link to Turnstile Data'] = name
    else:
        change_name_stations_to_extract_from_turnstile.append('None for '+name)
        

print(stations_to_extract_from_turnstile)
# Out:
# ['96 ST', 'BOWLING GREEN', 'SOUTH FERRY', '86 ST', '28 ST', '28 ST', 'CANAL ST', 'RECTOR ST', 'CHAMBERS ST', 'WALL ST', 'EAST BROADWAY', 'GRAND ST', 'BOWERY', 'BROAD ST', '2 AV', '51 ST', '7 AV', 'PRINCE ST', 'CANAL ST', '23 ST', 'ASTOR PL', 'BLEECKER ST', 'SPRING ST', '33 ST', '1 AV', 'CANAL ST', '14 ST', '3 AV', 'SPRING ST', '23 ST', '28 ST', '50 ST', 'HOUSTON ST', '18 ST', 'FRANKLIN ST', '72 ST', '77 ST', '96 ST', 'DYCKMAN ST', '125 ST', '125 ST', '135 ST', '145 ST', '79 ST', '86 ST', '110 ST', '116 ST', '103 ST', '125 ST', '155 ST', '116 ST', '103 ST', '116 ST', '14 ST', '57 ST', 'CITY HALL', '155 ST', 'CHAMBERS ST', 'PARK PLACE', 'CORTLANDT ST', 'RECTOR ST', '23 ST', 'DYCKMAN ST', '168 ST', '181 ST', '191 ST', '207 ST', '215 ST', '145 ST', '157 ST', '103 ST', '72 ST', '86 ST', '96 ST', 'CANAL ST', '9TH STREET', '14 ST', '14 ST', '33 ST', 'FULTON ST', 'WALL ST', '125 ST', '145 ST', '181 ST', '190 ST', '23 ST', '23 ST', 'CHRISTOPHER ST', '135 ST', '86 ST', '96 ST', '72 ST', 'CANAL ST', '175 ST', '50 ST', '59 ST', 'CHAMBERS ST', 'FULTON ST', '49 ST', '23 ST', '8 AV', '6 AV', 'CANAL ST', '168 ST', 'FULTON ST', 'FULTON ST']

# %%
subway.head(20)
# Out:
#                              name           short_name        lat        lon  \
# 0                     96TH STREET                96 ST  40.794379 -73.972000
# 1                   BOWLING GREEN                 NONE  40.704509 -74.014095
# 2                     SOUTH FERRY                 NONE  40.701710 -74.013149
# 3                     86TH STREET                86 ST  40.779494 -73.955529
# 4                     28TH STREET                28 ST  40.743314 -73.984075
# 5        14TH STREET–UNION SQUARE       14 ST–UNION SQ  40.735761 -73.990649
# 6                     28TH STREET                28 ST  40.745494 -73.988691
# 7                    CANAL STREET             CANAL ST  40.718092 -73.999892
# 8       BROADWAY–LAFAYETTE STREET   B’WAY–LAFAYETTE ST  40.725297 -73.996204
# 9                      5TH AVENUE                 5 AV  40.753743 -73.981900
# 10      42ND STREET–GRAND CENTRAL  42 ST–GRAND CENTRAL  40.751772 -73.976825
# 11         5TH AVENUE–59TH STREET           5 AV–59 ST  40.764827 -73.972675
# 12            HARLEM–148TH STREET        HARLEM–148 ST  40.823712 -73.936101
# 13  163RD STREET–AMSTERDAM AVENUE  163 ST–AMSTERDAM AV  40.836945 -73.940126
# 14                  RECTOR STREET            RECTOR ST  40.707363 -74.013850
# 15                  WTC CORTLANDT                 NONE  40.711115 -74.012270
# 16                CHAMBERS STREET          CHAMBERS ST  40.715508 -74.009245
# 17                    WALL STREET              WALL ST  40.706724 -74.009183
# 18                  EAST BROADWAY        EAST BROADWAY  40.713715 -73.990173
# 19                   GRAND STREET             GRAND ST  40.718162 -73.993784
#
#    Link to Turnstile Data
# 0                   96 ST
# 1           BOWLING GREEN
# 2             SOUTH FERRY
# 3                   86 ST
# 4                   28 ST
# 5                    None
# 6                   28 ST
# 7                CANAL ST
# 8                    None
# 9                    None
# 10                   None
# 11                   None
# 12                   None
# 13                   None
# 14              RECTOR ST
# 15                   None
# 16            CHAMBERS ST
# 17                WALL ST
# 18          EAST BROADWAY
# 19               GRAND ST

# %%
print(change_name_stations_to_extract_from_turnstile)
#will need to change these names manually
# Out:
# ['None for 14TH STREET–UNION SQUARE', 'None for BROADWAY–LAFAYETTE STREET', 'None for 5TH AVENUE', 'None for 42ND STREET–GRAND CENTRAL', 'None for 5TH AVENUE–59TH STREET', 'None for HARLEM–148TH STREET', 'None for 163RD STREET–AMSTERDAM AVENUE', 'None for WTC CORTLANDT', 'None for WEST 4TH STREET–WASHINGTON SQUARE', 'None for ESSEX STREET', 'None for LEXINGTON AVENUE–63RD STREET', 'None for 42ND STREET–BRYANT PARK', 'None for LEXINGTON AVENUE–59TH STREET', 'None for 5TH AVENUE–53RD STREET', 'None for 57TH STREET–7TH AVENUE', 'None for 8TH STREET–NEW YORK UNIVERSITY', 'None for 42ND STREET–PORT AUTHORITY BUS TERMINAL', 'None for ROOSEVELT ISLAND', 'None for NEW YORK PENN STATION', 'None for 66TH STREET–LINCOLN CENTER', 'None for WORLD TRADE CENTER', 'None for CENTRAL PARK NORTH–110TH STREET', 'None for BROOKLYN BRIDGE–CITY HALL', 'None for 42ND STREET–TIMES SQUARE', 'None for MARBLE HILL–225TH STREET', 'None for 137TH STREET–CITY COLLEGE', 'None for CATHEDRAL PARKWAY–110TH STREET', 'None for 116TH STREET–COLUMBIA UNIVERSITY', 'None for 34TH STREET–PENN STATION', 'None for 42ND STREET–TIMES SQUARE', 'None for CHRISTOPHER STREET–SHERIDAN SQUARE', 'None for CATHEDRAL PARKWAY–110TH STREET', 'None for 68TH STREET–HUNTER COLLEGE', 'None for 34TH STREET–PENN STATION', 'None for LEXINGTON AVENUE–53RD STREET', 'None for 47TH–50TH STREETS–ROCKEFELLER CENTER', 'None for DELANCEY STREET', 'None for 34TH STREET–HERALD SQUARE', 'None for 81ST STREET–MUSEUM OF NATURAL HISTORY', 'None for 59TH STREET–COLUMBUS CIRCLE', 'None for WHITEHALL STREET–SOUTH FERRY', 'None for WORLD TRADE CENTER', 'None for 14TH STREET–UNION SQUARE', 'None for GRAND CENTRAL', 'None for 42ND STREET–GRAND CENTRAL', 'None for INWOOD–207TH STREET', 'None for HARLEM–125TH STREET', 'None for GRAND CENTRAL TERMINAL', 'None for MARBLE HILL', 'None for MANHATTAN', 'None for 34TH STREET–HERALD SQUARE', 'None for UNION SQUARE', 'None for 34TH STREET–HUDSON YARDS', 'None for 59TH STREET–COLUMBUS CIRCLE', 'None for 42ND STREET–TIMES SQUARE', 'None for TIMES SQUARE']

# %%
print(len(change_name_stations_to_extract_from_turnstile))
# Out:
# 56

# %%
change_name_stations_to_extract_from_turnstile.append('14 ST-UNION SQ')
change_name_stations_to_extract_from_turnstile.append('B\'WAY-LAFAYETTE')
change_name_stations_to_extract_from_turnstile.append('5 AVE')
change_name_stations_to_extract_from_turnstile.append('GRD CNTRL-42 ST')
change_name_stations_to_extract_from_turnstile.append('5 AV/59 ST')
change_name_stations_to_extract_from_turnstile.append('HARLEM 148 ST')
change_name_stations_to_extract_from_turnstile.append('163 ST-AMSTERDM')
change_name_stations_to_extract_from_turnstile.append('WTC-CORTLANDT')
change_name_stations_to_extract_from_turnstile.append('W 4 ST-WASH SQ')
change_name_stations_to_extract_from_turnstile.append('DELANCEY/ESSEX')
change_name_stations_to_extract_from_turnstile.append('LEXINGTON AV/63')
change_name_stations_to_extract_from_turnstile.append('42 ST-BRYANT PK')
change_name_stations_to_extract_from_turnstile.append('None')
change_name_stations_to_extract_from_turnstile.append('5 AV/53 ST')
change_name_stations_to_extract_from_turnstile.append('57 ST-7 AV')
change_name_stations_to_extract_from_turnstile.append('8 ST-NYU')
change_name_stations_to_extract_from_turnstile.append('None as bus terminal')
change_name_stations_to_extract_from_turnstile.append('ROOSEVELT ISLND')
change_name_stations_to_extract_from_turnstile.append('34 ST-PENN STA')
change_name_stations_to_extract_from_turnstile.append('66 ST-LINCOLN')
change_name_stations_to_extract_from_turnstile.append('WORLD TRADE CTR')
change_name_stations_to_extract_from_turnstile.append('CENTRAL PK N110')
change_name_stations_to_extract_from_turnstile.append('BROOKLYN BRIDGE')
change_name_stations_to_extract_from_turnstile.append('TIMES SQ-42 ST')
change_name_stations_to_extract_from_turnstile.append('MARBLE HILL-225')
change_name_stations_to_extract_from_turnstile.append('137 ST CITY COL')
change_name_stations_to_extract_from_turnstile.append('CATHEDRAL PKWY')
change_name_stations_to_extract_from_turnstile.append('116 ST-COLUMBIA')
change_name_stations_to_extract_from_turnstile.append('34 ST-PENN STA')
change_name_stations_to_extract_from_turnstile.append('TIMES SQ-42 ST')
change_name_stations_to_extract_from_turnstile.append('CHRISTOPHER ST')
change_name_stations_to_extract_from_turnstile.append('CATHEDRAL PKWY')
change_name_stations_to_extract_from_turnstile.append('68ST-HUNTER CO')
change_name_stations_to_extract_from_turnstile.append('34 ST-PENN STA')
change_name_stations_to_extract_from_turnstile.append('LEXINGTON AV/53')
change_name_stations_to_extract_from_turnstile.append('47-50 STS ROCK')
change_name_stations_to_extract_from_turnstile.append('DELANCEY/ESSEX')
change_name_stations_to_extract_from_turnstile.append('34 ST-HERALD SQ')
change_name_stations_to_extract_from_turnstile.append('81 ST-MUSEUM')
change_name_stations_to_extract_from_turnstile.append('59 ST COLUMBUS')
change_name_stations_to_extract_from_turnstile.append('WHITEHALL S-FRY')
change_name_stations_to_extract_from_turnstile.append('WORLD TRADE CTR')
change_name_stations_to_extract_from_turnstile.append('14 ST-UNION SQ')
change_name_stations_to_extract_from_turnstile.append('GRD CNTRL-42 ST')
change_name_stations_to_extract_from_turnstile.append('GRD CNTRL-42 ST')
change_name_stations_to_extract_from_turnstile.append('INWOOD-207 ST')
change_name_stations_to_extract_from_turnstile.append('125 ST')
change_name_stations_to_extract_from_turnstile.append('MARBLE HILL-225')
change_name_stations_to_extract_from_turnstile.append('GRD CNTRL-42 ST')
change_name_stations_to_extract_from_turnstile.append('34 ST-HERALD SQ')
change_name_stations_to_extract_from_turnstile.append('14 ST-UNION SQ')
change_name_stations_to_extract_from_turnstile.append('34 ST-HUDSON YD')
change_name_stations_to_extract_from_turnstile.append('59 ST COLUMBUS')
change_name_stations_to_extract_from_turnstile.append('TIMES SQ-42 ST')
change_name_stations_to_extract_from_turnstile.append('TIMES SQ-42 ST')
change_name_stations_to_extract_from_turnstile.append('TIMES SQ-42 ST')

# %%
len(change_name_stations_to_extract_from_turnstile)
# Out:
# 112

# %% [markdown]
# - Missing for LEXINGTON AVENUE–59TH STREET
#
# - Have a triple of penn station 34 st
# - Duplicate of TIMES SQ-42 ST
# - Duplicate of CATHEDRAL PKWY
# - Duplicate of DELANCEY/ESSEX
# - Duplicate of WORLD TRADE CTR
# - Duplicate of 14 ST-UNION SQ
# - Quadruple of GRD CNTRL-42 ST
# - Duplicate of 125 ST
# - Duplicate of MARBLE HILL-225
# -

# %%
stations_to_extract_from_turnstile = []
j=56
#change_name_stations_to_extract_from_turnstile = []
for i in range(len(subway)):
    name = subway.iloc[i]['name']
    short_name = subway.iloc[i]['short_name']
    if short_name in turn_data['Station'].values:
        stations_to_extract_from_turnstile.append(short_name)
        subway.loc[i,'Link to Turnstile Data'] = short_name
    elif name in turn_data['Station'].values:
        stations_to_extract_from_turnstile.append(name)
        subway.loc[i,'Link to Turnstile Data'] = name
    else:
        subway.loc[i,'Link to Turnstile Data'] = change_name_stations_to_extract_from_turnstile[j]
        j=j+1

subway.head(20)
# Out:
#                              name           short_name        lat        lon  \
# 0                     96TH STREET                96 ST  40.794379 -73.972000
# 1                   BOWLING GREEN                 NONE  40.704509 -74.014095
# 2                     SOUTH FERRY                 NONE  40.701710 -74.013149
# 3                     86TH STREET                86 ST  40.779494 -73.955529
# 4                     28TH STREET                28 ST  40.743314 -73.984075
# 5        14TH STREET–UNION SQUARE       14 ST–UNION SQ  40.735761 -73.990649
# 6                     28TH STREET                28 ST  40.745494 -73.988691
# 7                    CANAL STREET             CANAL ST  40.718092 -73.999892
# 8       BROADWAY–LAFAYETTE STREET   B’WAY–LAFAYETTE ST  40.725297 -73.996204
# 9                      5TH AVENUE                 5 AV  40.753743 -73.981900
# 10      42ND STREET–GRAND CENTRAL  42 ST–GRAND CENTRAL  40.751772 -73.976825
# 11         5TH AVENUE–59TH STREET           5 AV–59 ST  40.764827 -73.972675
# 12            HARLEM–148TH STREET        HARLEM–148 ST  40.823712 -73.936101
# 13  163RD STREET–AMSTERDAM AVENUE  163 ST–AMSTERDAM AV  40.836945 -73.940126
# 14                  RECTOR STREET            RECTOR ST  40.707363 -74.013850
# 15                  WTC CORTLANDT                 NONE  40.711115 -74.012270
# 16                CHAMBERS STREET          CHAMBERS ST  40.715508 -74.009245
# 17                    WALL STREET              WALL ST  40.706724 -74.009183
# 18                  EAST BROADWAY        EAST BROADWAY  40.713715 -73.990173
# 19                   GRAND STREET             GRAND ST  40.718162 -73.993784
#
#    Link to Turnstile Data
# 0                   96 ST
# 1           BOWLING GREEN
# 2             SOUTH FERRY
# 3                   86 ST
# 4                   28 ST
# 5          14 ST-UNION SQ
# 6                   28 ST
# 7                CANAL ST
# 8         B'WAY-LAFAYETTE
# 9                   5 AVE
# 10        GRD CNTRL-42 ST
# 11             5 AV/59 ST
# 12          HARLEM 148 ST
# 13        163 ST-AMSTERDM
# 14              RECTOR ST
# 15          WTC-CORTLANDT
# 16            CHAMBERS ST
# 17                WALL ST
# 18          EAST BROADWAY
# 19               GRAND ST

# %%
#show the entire data frame
#pd.set_option('display.max_rows', None)
#subway

# %%
#remove any row that has a duplicate value in the link to turnstile data column
subway = subway.drop_duplicates(subset=['Link to Turnstile Data'], keep='first')
len(subway)
# Out:
# 96

# %% [markdown]
# ### Now have 96 subway locations in Manhattan that we can reference in the turnstile data

# %% [markdown]
# #### is is it 146 from station_link?

# %%
#station_link['station']
man_turn_data = pd.merge(stations_link, turn_data, left_on='station', right_on='Station')
man_turn_data.head(20)
# Out:
#    station line_names division    borough subregion    C/A  Unit       SCP  \
# 0     1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-00
# 1     1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-00-00
# 2     1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-01
# 3     1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-02
# 4     1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-00-01
# 5     1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-01
# 6     1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-00
# 7     1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-04
# 8     1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-03
# 9     1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-02
# 10    1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-02
# 11    1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-00-01
# 12    1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-01
# 13    1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-00-00
# 14    1 AV          L      BMT  Manhattan  14 to 42   H007  R248  00-03-00
# 15    1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-01
# 16    1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-04
# 17    1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-03
# 18    1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-02
# 19    1 AV          L      BMT  Manhattan  14 to 42  H007A  R248  02-03-00
#
#    Station Line Name Division        Date      Time Description    Entries  \
# 0     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR  370818021
# 1     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR   15302393
# 2     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR    2569788
# 3     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR    6577135
# 4     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR   60949253
# 5     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR      14996
# 6     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR       3835
# 7     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR      84669
# 8     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR      50430
# 9     1 AV         L      BMT  12/27/2019  03:00:00     REGULAR      32577
# 10    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR    6577154
# 11    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR   60949311
# 12    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR    2569795
# 13    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR   15302456
# 14    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR  370818038
# 15    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR      14999
# 16    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR      84706
# 17    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR      50447
# 18    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR      32584
# 19    1 AV         L      BMT  12/27/2019  07:00:00     REGULAR       3835
#
#     Exits
# 0                                           387993138
# 1                                            17102988
# 2                                             1109743
# 3                                              553888
# 4                                            38064126
# 5                                              117639
# 6                                              192369
# 7                                               12012
# 8                                               29628
# 9                                               62861
# 10                                             553892
# 11                                           38064297
# 12                                            1109755
# 13                                           17103257
# 14                                          387993181
# 15                                             117730
# 16                                              12033
# 17                                              29656
# 18                                              62904
# 19                                             192495

# %%
#trim the csv data to a new file containg the stations in manhattan
#this will be the data we use for the rest of the project

man_turn_data = pd.DataFrame(columns=turn_data.columns)  # Initialize an empty DataFrame with the same columns as turn_data
'''
for i in range(len(subway)):
    station_to_find=subway['Link to Turnstile Data'][i]
    print(station_to_find)
    for j in range(len(turn_data)):
        if turn_data['Station'][j] == station_to_find:
            man_turn_data = man_turn_data.append(turn_data.iloc[j], ignore_index=True)

man_turn_data
'''
# Out:
# "\nfor i in range(len(subway)):\n    station_to_find=subway['Link to Turnstile Data'][i]\n    print(station_to_find)\n    for j in range(len(turn_data)):\n        if turn_data['Station'][j] == station_to_find:\n            man_turn_data = man_turn_data.append(turn_data.iloc[j], ignore_index=True)\n\nman_turn_data\n"

# %%
man_turn_data = pd.merge(subway, turn_data, left_on='Link to Turnstile Data', right_on='Station')

# %%
man_turn_data.head(10)
# Out:
#           name short_name        lat     lon Link to Turnstile Data    C/A  \
# 0  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 1  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 2  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 3  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 4  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 5  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 6  96TH STREET      96 ST  40.794379 -73.972                  96 ST  R168A
# 7  96TH STREET      96 ST  40.794379 -73.972                  96 ST   R169
# 8  96TH STREET      96 ST  40.794379 -73.972                  96 ST   R169
# 9  96TH STREET      96 ST  40.794379 -73.972                  96 ST   R169
#
#    Unit       SCP Station Line Name Division        Date      Time  \
# 0  R168  00-00-02   96 ST       123      IRT  12/27/2019  00:00:00
# 1  R168  00-02-00   96 ST       123      IRT  12/27/2019  00:00:00
# 2  R168  00-03-02   96 ST       123      IRT  12/27/2019  00:00:00
# 3  R168  00-00-00   96 ST       123      IRT  12/27/2019  00:00:00
# 4  R168  00-00-01   96 ST       123      IRT  12/27/2019  00:00:00
# 5  R168  00-03-01   96 ST       123      IRT  12/27/2019  00:00:00
# 6  R168  00-03-00   96 ST       123      IRT  12/27/2019  00:00:00
# 7  R168  01-00-01   96 ST       123      IRT  12/27/2019  00:00:00
# 8  R168  01-03-02   96 ST       123      IRT  12/27/2019  00:00:00
# 9  R168  01-05-01   96 ST       123      IRT  12/27/2019  00:00:00
#
#   Description   Entries  \
# 0     REGULAR   7050714
# 1     REGULAR   6592911
# 2     REGULAR  11982395
# 3     REGULAR   1875264
# 4     REGULAR   6189156
# 5     REGULAR   4028999
# 6     REGULAR   4580292
# 7     REGULAR   1620619
# 8     REGULAR   9245121
# 9     REGULAR         0
#
#    Exits
# 0                                            3195113
# 1                                            7757191
# 2                                           11692946
# 3                                            1933375
# 4                                            2545523
# 5                                            5063535
# 6                                           10195272
# 7                                             988385
# 8                                            8843365
# 9                                               1607

# %%
len(man_turn_data)
#4.5 million rows, which is 5.6 less than the original
# Out:
# 4576249

# %% [markdown]
# ### feature selection

# %%
#lets drop:
#short_name, link to turnstile data, Unit,  Line Name, Division
# if desc is recover aud disregard those rows?
man_turn_data.drop(['short_name','Link to Turnstile Data','Unit','Line Name','Division'], axis=1, inplace=True)

# %%
man_turn_data.head(20)
# Out:
#            name        lat     lon    C/A       SCP Station        Date  \
# 0   96TH STREET  40.794379 -73.972  R168A  00-00-02   96 ST  12/27/2019
# 1   96TH STREET  40.794379 -73.972  R168A  00-02-00   96 ST  12/27/2019
# 2   96TH STREET  40.794379 -73.972  R168A  00-03-02   96 ST  12/27/2019
# 3   96TH STREET  40.794379 -73.972  R168A  00-00-00   96 ST  12/27/2019
# 4   96TH STREET  40.794379 -73.972  R168A  00-00-01   96 ST  12/27/2019
# 5   96TH STREET  40.794379 -73.972  R168A  00-03-01   96 ST  12/27/2019
# 6   96TH STREET  40.794379 -73.972  R168A  00-03-00   96 ST  12/27/2019
# 7   96TH STREET  40.794379 -73.972   R169  01-00-01   96 ST  12/27/2019
# 8   96TH STREET  40.794379 -73.972   R169  01-03-02   96 ST  12/27/2019
# 9   96TH STREET  40.794379 -73.972   R169  01-05-01   96 ST  12/27/2019
# 10  96TH STREET  40.794379 -73.972   R169  01-07-00   96 ST  12/27/2019
# 11  96TH STREET  40.794379 -73.972   R169  01-00-04   96 ST  12/27/2019
# 12  96TH STREET  40.794379 -73.972   R169  01-03-01   96 ST  12/27/2019
# 13  96TH STREET  40.794379 -73.972   R169  01-03-05   96 ST  12/27/2019
# 14  96TH STREET  40.794379 -73.972   R169  01-00-00   96 ST  12/27/2019
# 15  96TH STREET  40.794379 -73.972   R169  01-00-03   96 ST  12/27/2019
# 16  96TH STREET  40.794379 -73.972   R169  01-03-03   96 ST  12/27/2019
# 17  96TH STREET  40.794379 -73.972   R169  01-00-02   96 ST  12/27/2019
# 18  96TH STREET  40.794379 -73.972   R169  01-07-01   96 ST  12/27/2019
# 19  96TH STREET  40.794379 -73.972   R169  01-03-00   96 ST  12/27/2019
#
#         Time Description   Entries  \
# 0   00:00:00     REGULAR   7050714
# 1   00:00:00     REGULAR   6592911
# 2   00:00:00     REGULAR  11982395
# 3   00:00:00     REGULAR   1875264
# 4   00:00:00     REGULAR   6189156
# 5   00:00:00     REGULAR   4028999
# 6   00:00:00     REGULAR   4580292
# 7   00:00:00     REGULAR   1620619
# 8   00:00:00     REGULAR   9245121
# 9   00:00:00     REGULAR         0
# 10  00:00:00     REGULAR  67110761
# 11  00:00:00     REGULAR    754268
# 12  00:00:00     REGULAR   1467020
# 13  00:00:00     REGULAR  22525135
# 14  00:00:00     REGULAR   1789165
# 15  00:00:00     REGULAR   3219007
# 16  00:00:00     REGULAR  10599617
