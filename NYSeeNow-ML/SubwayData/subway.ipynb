# %% [markdown]
# ### This notebook will be for processing and cleaning the subway turnstile dataset for 2019
# - Will need to determine all the turnstile differences for entries between current and last value
# - Same for exits
# - This can give me a representation of how many people enter/exit station X in a given time period
# - Do this for only stations in Manhattan

# %%
import json
import pandas as pd

# %% [markdown]
# ### Explanation of linking the 3 datasets to get useful information:
# - turnstile_data is the dataset obtained from: https://data.ny.gov/Transportation/Turnstile-Usage-Data-2019/xfn5-qji9
# - This dataset contains all the info in 2019 for all the turnstiles in the MTA system
# - station_data is a dataset obtained from: http://web.mta.info/developers/data/nyct/subway/Stations.csv
# - This dataset contains information for all the stations in the MTA system
# - The problem that occurs is how to link the two datasets together
# - lookup_data provides a link between the two in the form of a column named remote or unit id that links each remote unit id to each station

# %%
turnstile_data = pd.read_csv('Turnstile_Usage_Data__2019.csv')
turnstile_data.head()
# Out:
#     C/A  Unit       SCP         Station Line Name Division        Date  \
# 0  A033  R170  02-00-05  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 1  A033  R170  02-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 2  A033  R170  02-06-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 3  A033  R170  02-00-03  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 4  A033  R170  02-06-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
#
#        Time Description   Entries  \
# 0  00:00:00     REGULAR  17538854
# 1  00:00:00     REGULAR  14983900
# 2  00:00:00     REGULAR    769115
# 3  00:00:00     REGULAR   7191422
# 4  00:00:00     REGULAR  71047673
#
#    Exits
# 0                                            7031168
# 1                                           14554087
# 2                                             559221
# 3                                            8417203
# 4                                           20925389

# %%
with open('stations.csv') as file:
    station_data = pd.read_csv(file)
station_data.head()
# Out:
#    ogc_fid  station id complex id gtfs stop id division     line  \
# 0        1         1.0          1          R01      BMT  Astoria
# 1        2         2.0          2          R03      BMT  Astoria
# 2        3         3.0          3          R04      BMT  Astoria
# 3        4         4.0          4          R05      BMT  Astoria
# 4        5         5.0          5          R06      BMT  Astoria
#
#                 stop name borough daytime routes structure  gtfs latitude  \
# 0  Astoria - Ditmars Blvd       Q            N W  Elevated      40.775036
# 1            Astoria Blvd       Q            N W  Elevated      40.770258
# 2                   30 Av       Q            N W  Elevated      40.766779
# 3                Broadway       Q            N W  Elevated      40.761820
# 4                   36 Av       Q            N W  Elevated      40.756804
#
#    gtfs longitude   north direction label south direction label
# 0      -73.912034                     NaN             Manhattan
# 1      -73.917843            Ditmars Blvd             Manhattan
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan

# %%
with open('remote_complex_lookup.csv') as file:
    lookup_data = pd.read_csv(file)
lookup_data.head()
# Out:
#   remote   booth  complex_id       station line_name division
# 0    R001   A060       635.0  WHITEHALL ST        R1      BMT
# 1    R001   A058       635.0  WHITEHALL ST        R1      BMT
# 2    R001  R101S       635.0   SOUTH FERRY        R1      IRT
# 3    R002   A077       628.0     FULTON ST  ACJZ2345      BMT
# 4    R002   A081       628.0     FULTON ST  ACJZ2345      BMT

# %%
#count the number of null values for complex id
lookup_data['complex_id'].isnull().sum()
# Out:
# 36

# %%
#change the complex id column to object instead of float
lookup_data['complex_id'] = lookup_data['complex_id'].astype(str)
lookup_data.head()
# Out:
#   remote   booth complex_id       station line_name division
# 0    R001   A060      635.0  WHITEHALL ST        R1      BMT
# 1    R001   A058      635.0  WHITEHALL ST        R1      BMT
# 2    R001  R101S      635.0   SOUTH FERRY        R1      IRT
# 3    R002   A077      628.0     FULTON ST  ACJZ2345      BMT
# 4    R002   A081      628.0     FULTON ST  ACJZ2345      BMT

# %% [markdown]
# ### First lets look at all the station_data dataset
# - First I will drop all rows that are not in Manhattan

# %%
for i in range(len(station_data)):
    if station_data['borough'][i] == 'Q' or  station_data['borough'][i] == 'Bk' or station_data['borough'][i] == 'Bx'or station_data['borough'][i] == 'SI':
        station_data.drop(i, inplace=True)

station_data.head()
# Out:
#     ogc_fid  station id complex id gtfs stop id division                 line  \
# 6         7         7.0        613          R11      BMT              Astoria
# 7         8         8.0          8          R13      BMT              Astoria
# 8         9         9.0          9          R14      BMT  Broadway - Brighton
# 9        10        10.0         10          R15      BMT  Broadway - Brighton
# 10       11        11.0        611          R16      BMT  Broadway - Brighton
#
#              stop name borough daytime routes structure  gtfs latitude  \
# 6   Lexington Av/59 St       M          N W R    Subway      40.762660
# 7           5 Av/59 St       M          N W R    Subway      40.764811
# 8         57 St - 7 Av       M        N Q R W    Subway      40.764664
# 9                49 St       M          N R W    Subway      40.759901
# 10    Times Sq - 42 St       M        N Q R W    Subway      40.754672
#
#     gtfs longitude north direction label south direction label
# 6       -73.967258                Queens   Downtown & Brooklyn
# 7       -73.973347                Queens   Downtown & Brooklyn
# 8       -73.980658       Uptown & Queens   Downtown & Brooklyn
# 9       -73.984139       Uptown & Queens   Downtown & Brooklyn
# 10      -73.986754       Uptown & Queens   Downtown & Brooklyn

# %%
station_data.tail(20)
# Out:
#      ogc_fid  station id complex id gtfs stop id division       line  \
# 472      473       475.0        475          Q05      IND  Second Av
# 473      474       476.0        476          Q04      IND  Second Av
# 474      475       477.0        477          Q03      IND  Second Av
# 496      497         NaN       R468          NaN      RIT        NaN
# 497      498         NaN       R469          NaN      RIT        NaN
# 498      499         NaN       R540          NaN      PTH        NaN
# 499      500         NaN       R541          NaN      PTH        NaN
# 500      501         NaN       R542          NaN      PTH        NaN
# 501      502         NaN       R543          NaN      PTH        NaN
# 502      503         NaN       R544          NaN      PTH        NaN
# 503      504         NaN       R545          NaN      PTH        NaN
# 504      505         NaN       R546          NaN      PTH        NaN
# 505      506         NaN       R547          NaN      PTH        NaN
# 506      507         NaN       R548          NaN      PTH        NaN
# 507      508         NaN       R549          NaN      PTH        NaN
# 508      509         NaN       R550          NaN      PTH        NaN
# 509      510         NaN       R551          NaN      PTH        NaN
# 510      511         NaN       R552          NaN      PTH        NaN
# 511      512         NaN       R535          NaN      JFK        NaN
# 512      513         NaN       R536          NaN      JFK        NaN
#
#                              stop name borough daytime routes structure  \
# 472                              96 St       M              Q    Subway
# 473                              86 St       M              Q    Subway
# 474                              72 St       M              Q    Subway
# 496  Roosevelt Island Tram - Eastbound     NaN            NaN       NaN
# 497  Roosevelt Island Tram - Westbound     NaN            NaN       NaN
# 498                 World Trade Center     NaN            NaN       NaN
# 499                              33 St     NaN            NaN       NaN
# 500                              23 St     NaN            NaN       NaN
# 501                        Exchange Pl     NaN            NaN       NaN
# 502                           Harrison     NaN            NaN       NaN
# 503                              14 St     NaN            NaN       NaN
# 504                    Pavonia/Newport     NaN            NaN       NaN
# 505                               9 St     NaN            NaN       NaN
# 506                     Christopher St     NaN            NaN       NaN
# 507                Newark Penn Station     NaN            NaN       NaN
# 508                            Hoboken     NaN            NaN       NaN
# 509                           Grove St     NaN            NaN       NaN
# 510                         Journal Sq     NaN            NaN       NaN
# 511                       Howard Beach     NaN            NaN       NaN
# 512                            Jamaica     NaN            NaN       NaN
#
#      gtfs latitude  gtfs longitude north direction label south direction label
# 472      40.784318      -73.947152                   NaN   Downtown & Brooklyn
# 473      40.777891      -73.951787                Uptown   Downtown & Brooklyn
# 474      40.768799      -73.958424                Uptown   Downtown & Brooklyn
# 496      40.761186      -73.964191                   NaN                   NaN
# 497      40.757307      -73.954097                   NaN                   NaN
# 498      40.712052      -74.014129                   NaN                   NaN
# 499      40.747850      -73.989875                   NaN                   NaN
# 500      40.742672      -73.994177                   NaN                   NaN
# 501      40.716554      -74.033372                   NaN                   NaN
# 502      40.740472      -74.157344                   NaN                   NaN
# 503      40.738507      -73.998741                   NaN                   NaN
# 504      40.725005      -74.038257                   NaN                   NaN
# 505      40.734409      -74.000463                   NaN                   NaN
# 506      40.732593      -74.008924                   NaN                   NaN
# 507      40.733585      -74.167920                   NaN                   NaN
# 508      40.734910      -74.033220                   NaN                   NaN
# 509      40.723621      -74.044832                   NaN                   NaN
# 510      40.730304      -74.068633                   NaN                   NaN
# 511      40.661051      -73.829638                   NaN                   NaN
# 512      40.698942      -73.808416                   NaN                   NaN

# %%
#take out the last 17 station names and put them in a list
station_names = station_data['stop name'].tail(17).tolist()
station_names
# Out:
# ['Roosevelt Island Tram - Eastbound',
#  'Roosevelt Island Tram - Westbound',
#  'World Trade Center',
#  '33 St',
#  '23 St',
#  'Exchange Pl',
#  'Harrison',
#  '14 St',
#  'Pavonia/Newport',
#  '9 St',
#  'Christopher St',
#  'Newark Penn Station',
#  'Hoboken',
#  'Grove St',
#  'Journal Sq',
#  'Howard Beach',
#  'Jamaica']

# %%
station_names_to_drop=['Roosevelt Island Tram - Eastbound',
 'Roosevelt Island Tram - Westbound',
 'Exchange Pl',
 'Harrison',
 'Pavonia/Newport',
 '9 St',
 'Newark Penn Station',
 'Hoboken',
 'Grove St',
 'Journal Sq',
 'Howard Beach',
 'Jamaica']

 # Create a boolean mask to identify rows with names are in the list
mask = station_data['stop name'].isin(station_names_to_drop)

# Apply the mask to drop the rows
station_data = station_data[~mask]

station_data.tail(10)
# Out:
#      ogc_fid  station id complex id gtfs stop id division  \
# 470      471       469.0        610          901      IRT
# 471      472       471.0        471          726      IRT
# 472      473       475.0        475          Q05      IND
# 473      474       476.0        476          Q04      IND
# 474      475       477.0        477          Q03      IND
# 498      499         NaN       R540          NaN      PTH
# 499      500         NaN       R541          NaN      PTH
# 500      501         NaN       R542          NaN      PTH
# 503      504         NaN       R545          NaN      PTH
# 506      507         NaN       R548          NaN      PTH
#
#                     line              stop name borough daytime routes  \
# 470  Lexington - Shuttle  Grand Central - 42 St       M              S
# 471             Flushing          34 St - 11 Av       M              7
# 472            Second Av                  96 St       M              Q
# 473            Second Av                  86 St       M              Q
# 474            Second Av                  72 St       M              Q
# 498                  NaN     World Trade Center     NaN            NaN
# 499                  NaN                  33 St     NaN            NaN
# 500                  NaN                  23 St     NaN            NaN
# 503                  NaN                  14 St     NaN            NaN
# 506                  NaN         Christopher St     NaN            NaN
#
#     structure  gtfs latitude  gtfs longitude north direction label  \
# 470    Subway      40.752769      -73.979189              Times Sq
# 471    Subway      40.755882      -74.001910                Queens
# 472    Subway      40.784318      -73.947152                   NaN
# 473    Subway      40.777891      -73.951787                Uptown
# 474    Subway      40.768799      -73.958424                Uptown
# 498       NaN      40.712052      -74.014129                   NaN
# 499       NaN      40.747850      -73.989875                   NaN
# 500       NaN      40.742672      -73.994177                   NaN
# 503       NaN      40.738507      -73.998741                   NaN
# 506       NaN      40.732593      -74.008924                   NaN
#
#     south direction label
# 470                   NaN
# 471                   NaN
# 472   Downtown & Brooklyn
# 473   Downtown & Brooklyn
# 474   Downtown & Brooklyn
# 498                   NaN
# 499                   NaN
# 500                   NaN
# 503                   NaN
# 506                   NaN

# %%
#set the last 5 rows column[gtfs stop id] to the complex id value
station_data.loc[station_data.tail(5).index, 'gtfs stop id'] = station_data['complex id'].tail(5)

# %%
#change complex id in station to have .0 and be of type string
station_data['complex id'] = station_data['complex id'].astype(str)
station_data['complex id'] = station_data['complex id'] + '.0'

# %% [markdown]
# ### Now match up complex_id in station_data with complex_id in lookup_data

# %%
station_remote_info = pd.merge(station_data, lookup_data, left_on='complex id', right_on='complex_id')
station_remote_info.head()
# Out:
#    ogc_fid  station id complex id gtfs stop id division_x     line  \
# 0        7         7.0      613.0          R11        BMT  Astoria
# 1        7         7.0      613.0          R11        BMT  Astoria
# 2        7         7.0      613.0          R11        BMT  Astoria
# 3        7         7.0      613.0          R11        BMT  Astoria
# 4        7         7.0      613.0          R11        BMT  Astoria
#
#             stop name borough daytime routes structure  gtfs latitude  \
# 0  Lexington Av/59 St       M          N W R    Subway       40.76266
# 1  Lexington Av/59 St       M          N W R    Subway       40.76266
# 2  Lexington Av/59 St       M          N W R    Subway       40.76266
# 3  Lexington Av/59 St       M          N W R    Subway       40.76266
# 4  Lexington Av/59 St       M          N W R    Subway       40.76266
#
#    gtfs longitude north direction label south direction label remote   booth  \
# 0      -73.967258                Queens   Downtown & Brooklyn    R016  N305A
# 1      -73.967258                Queens   Downtown & Brooklyn    R017   N306
# 2      -73.967258                Queens   Downtown & Brooklyn    R017   N305
# 3      -73.967258                Queens   Downtown & Brooklyn    R050   R244
# 4      -73.967258                Queens   Downtown & Brooklyn    R050  R244A
#
#   complex_id          station line_name division_y
# 0      613.0  LEXINGTON-53 ST       EM6        IND
# 1      613.0  LEXINGTON-53 ST       EM6        IND
# 2      613.0  LEXINGTON-53 ST       EM6        IND
# 3      613.0            59 ST    456NQR        IRT
# 4      613.0            59 ST    456NQR        IRT

# %%
#drop the following columns: ogc_fid, gtfs stop id, division_x, line, daytime routes, structure, north direction label, south direction label, line_name, division_y
station_remote_info.drop(['ogc_fid', 'station id', 'complex id','gtfs stop id', 'division_x', 'line', 'borough','daytime routes', 'structure', 'north direction label', 'south direction label', 'line_name', 'division_y'], axis=1, inplace=True)

station_remote_info.head()
# Out:
#             stop name  gtfs latitude  gtfs longitude remote   booth  \
# 0  Lexington Av/59 St       40.76266      -73.967258    R016  N305A
# 1  Lexington Av/59 St       40.76266      -73.967258    R017   N306
# 2  Lexington Av/59 St       40.76266      -73.967258    R017   N305
# 3  Lexington Av/59 St       40.76266      -73.967258    R050   R244
# 4  Lexington Av/59 St       40.76266      -73.967258    R050  R244A
#
#   complex_id          station
# 0      613.0  LEXINGTON-53 ST
# 1      613.0  LEXINGTON-53 ST
# 2      613.0  LEXINGTON-53 ST
# 3      613.0            59 ST
# 4      613.0            59 ST

# %%
#rename the columns:
station_remote_info.rename(columns={'remote ':'remote_unit_id','gtfs longitude':'lon','gtfs latitude': 'lat', 'stop name': 'station_name', 'station':'short_name'}, inplace=True)
station_remote_info.head()
# Out:
#          station_name       lat        lon remote_unit_id  booth complex_id  \
# 0  Lexington Av/59 St  40.76266 -73.967258           R016  N305A      613.0
# 1  Lexington Av/59 St  40.76266 -73.967258           R017   N306      613.0
# 2  Lexington Av/59 St  40.76266 -73.967258           R017   N305      613.0
# 3  Lexington Av/59 St  40.76266 -73.967258           R050   R244      613.0
# 4  Lexington Av/59 St  40.76266 -73.967258           R050  R244A      613.0
#
#         short_name
# 0  LEXINGTON-53 ST
# 1  LEXINGTON-53 ST
# 2  LEXINGTON-53 ST
# 3            59 ST
# 4            59 ST

# %%
len(station_remote_info)
# Out:
# 527

# %% [markdown]
# ### Lets now look at the turnstile_data dataset
# - First I should drop all the rows that concern Manhattan stations only

# %%
len(turnstile_data)
# Out:
# 10467101

# %%
#reduce the number of rows in turnstile data by only including matches for the following condition: 
#remote in remote=unit. This is a unique id for each subsection of a station
turnstile_data = turnstile_data[turnstile_data['Unit'].isin(station_remote_info['remote_unit_id'])]
len(turnstile_data)
# Out:
# 4617524

# %% [markdown]
# ### This should now be all the turnstile data for manhattan stations in 2019

# %% [markdown]
# - Use the remote_unit_id for linking a station to a turnstile
# - station_remote_info is useful as it has the station name, lat and lon and also a link to the turnstile data for that station
# - Can now proceed with processing the turnstile data

# %% [markdown]
# - I will convert date and time to unix timestamp, name: timestamp
# - I will combine C/A, Unit, SCP and the timestamp to create a unique identifier for each row, name: id
# - I will combine C/A, Unit and SCP to create a unique id for each, name: turnstile_id
# - I will calculate the entry and exit values for each row, name: entry_diff and exit_diff

# %%
#create a new dateframe name for turnstile data
turnstile_data_man = turnstile_data.copy()

# %%
turnstile_data_man.head()
# Out:
#     C/A  Unit       SCP         Station Line Name Division        Date  \
# 0  A033  R170  02-00-05  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 1  A033  R170  02-00-02  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 2  A033  R170  02-06-00  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 3  A033  R170  02-00-03  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
# 4  A033  R170  02-06-01  14 ST-UNION SQ  LNQR456W      BMT  12/27/2019
#
#        Time Description   Entries  \
# 0  00:00:00     REGULAR  17538854
# 1  00:00:00     REGULAR  14983900
# 2  00:00:00     REGULAR    769115
# 3  00:00:00     REGULAR   7191422
# 4  00:00:00     REGULAR  71047673
#
#    Exits
# 0                                            7031168
# 1                                           14554087
# 2                                             559221
# 3                                            8417203
# 4                                           20925389

# %%
#convert date and time to unix timestamp
turnstile_data_man['DateTime'] = pd.to_datetime(turnstile_data_man['Date'] + ' ' + turnstile_data_man['Time'])

turnstile_data_man['Timestamp'] = turnstile_data_man['DateTime'].apply(lambda x: x.timestamp())

# %%
#combine c/a, unit, and scp to create a unique id for each turnstile
turnstile_data_man['turnstile_id'] = turnstile_data_man['C/A'] +' '+ turnstile_data_man['Unit'] +' '+  turnstile_data_man['SCP']

# %%
#combine c/a, unit, scp, and timestamp to create a unique id for each turnstile at a given time
turnstile_data_man['id'] = turnstile_data_man['turnstile_id']+ ' '+  turnstile_data_man['Timestamp'].astype(str)

# %%
#can now drop c/a, scp, line name, divison,date, time, datetime
turnstile_data_man.drop(['C/A', 'SCP', 'Line Name', 'Division', 'Date', 'Time', 'DateTime'], axis=1, inplace=True)

# %%
turnstile_data_man.columns
# Out:
# Index(['Unit', 'Station', 'Description', 'Entries',
#        'Exits                                                     ',
#        'Timestamp', 'turnstile_id', 'id'],
#       dtype='object')

# %%
#re-orient the columns
#1st will be id, 2nd turnstile id, then unit, timestamp, station, entires,exits and description
new_order = ['id', 'turnstile_id', 'Unit', 'Timestamp', 'Station', 'Entries', 'Exits                                                     ', 'Description']
turnstile_data_man = turnstile_data_man[new_order]

# %%
#re-name the columns:
turnstile_data_man.rename(columns={'Unit':'remote_unit_id', 'Timestamp':'time_stamp','Station':'station_name', 'Entries':'entries', 'Exits                                                     ':'exits', 'Description':'description'}, inplace=True)
len(turnstile_data_man)
# Out:
# 4617524

# %%
#check for duplicate ids, Nan and other possible error values
#count duplicates:
# is it possible that entry and exit values differ for the duplicate id?
#create a new column
turnstile_data_man['check_dup']=turnstile_data_man['id']+' '+turnstile_data_man['entries'].astype(str)+' '+turnstile_data_man['exits'].astype(str)

duplicate_count = turnstile_data_man['id'].duplicated().sum()
print("Number of duplicates in 'id' column:", duplicate_count)
dup_count = turnstile_data_man['check_dup'].duplicated().sum()
print("Number of duplicates in check_dup column:", dup_count)
nan_count=turnstile_data_man.isnull().sum()
print("Number of null values in all columns:\n", nan_count)
# count the number of times "RECOVR AUD" appears in the description column
r_aud=turnstile_data_man['description'].str.contains('RECOVR AUD').sum()
print("Number of times 'RECOVR AUD' appears in the description column:", r_aud)
# Out:
# Number of duplicates in 'id' column: 181348
# Number of duplicates in check_dup column: 181211
# Number of null values in all columns:
#  id                0
# turnstile_id      0
# remote_unit_id    0
# time_stamp        0
# station_name      0
# entries           0
# exits             0
# description       0
# check_dup         0
# dtype: int64
# Number of times 'RECOVR AUD' appears in the description column: 21902

# %%
#drop column check_dup
turnstile_data_man.drop(['check_dup'], axis=1, inplace=True)
#drop all the duplicate id values as only 137 of them have diff entry and exit values
turnstile_data_man = turnstile_data_man.drop_duplicates(subset=['id'])

# %%
#sort by time stamp and name of station, drop all data before 1546300800
turnstile_data_man.sort_values(by=['time_stamp', 'station_name'], inplace=True)

#drop all data before 1546300800
turnstile_data_man = turnstile_data_man[turnstile_data_man['time_stamp'] >= 1546290000]

# %% [markdown]
# #### Left to do:
# - Calculate entry and exit differences for each turnstile
# - Drop the description column

# %%
len(turnstile_data_man)
# Out:
# 4399477

# %%
turnstile_data_man.head(50)
# Out:
#                                         id         turnstile_id  \
# 10406998   R138 R293 00-03-03 1546290000.0   R138 R293 00-03-03
# 10406999   R138 R293 00-02-05 1546290000.0   R138 R293 00-02-05
# 10407000   R138 R293 00-02-03 1546290000.0   R138 R293 00-02-03
# 10407001   R138 R293 00-00-02 1546290000.0   R138 R293 00-00-02
# 10407002   R138 R293 00-03-01 1546290000.0   R138 R293 00-03-01
# 10407003   R138 R293 00-06-00 1546290000.0   R138 R293 00-06-00
# 10407004   R138 R293 00-02-01 1546290000.0   R138 R293 00-02-01
# 10407005   R138 R293 00-03-00 1546290000.0   R138 R293 00-03-00
# 10407006   R138 R293 00-03-04 1546290000.0   R138 R293 00-03-04
# 10407007   R138 R293 00-00-03 1546290000.0   R138 R293 00-00-03
# 10407008   R138 R293 00-02-00 1546290000.0   R138 R293 00-02-00
# 10407009   R138 R293 00-03-02 1546290000.0   R138 R293 00-03-02
# 10407010   R138 R293 00-00-00 1546290000.0   R138 R293 00-00-00
# 10407011   R138 R293 00-02-04 1546290000.0   R138 R293 00-02-04
# 10407012   R138 R293 00-00-01 1546290000.0   R138 R293 00-00-01
# 10407013   R138 R293 00-00-04 1546290000.0   R138 R293 00-00-04
# 10407014   R138 R293 00-02-02 1546290000.0   R138 R293 00-02-02
# 10407015   R142 R293 01-06-00 1546290000.0   R142 R293 01-06-00
# 10407016   R142 R293 01-00-00 1546290000.0   R142 R293 01-00-00
# 10407017   R142 R293 01-06-01 1546290000.0   R142 R293 01-06-01
# 10407018   R142 R293 01-00-02 1546290000.0   R142 R293 01-00-02
# 10407019   R142 R293 01-00-03 1546290000.0   R142 R293 01-00-03
# 10407020   R142 R293 01-00-01 1546290000.0   R142 R293 01-00-01
# 10406958   N060 R010 01-00-05 1546290000.0   N060 R010 01-00-05
# 10406959   N060 R010 01-00-01 1546290000.0   N060 R010 01-00-01
# 10406960   N060 R010 01-00-03 1546290000.0   N060 R010 01-00-03
# 10406961   N060 R010 01-00-02 1546290000.0   N060 R010 01-00-02
# 10406962   N060 R010 01-00-00 1546290000.0   N060 R010 01-00-00
# 10406963   N060 R010 01-03-00 1546290000.0   N060 R010 01-03-00
# 10406964   N060 R010 01-05-00 1546290000.0   N060 R010 01-05-00
# 10406965   N060 R010 01-00-04 1546290000.0   N060 R010 01-00-04
# 10406966   N060 R010 01-05-01 1546290000.0   N060 R010 01-05-01
# 10406967  N062A R010 00-05-01 1546290000.0  N062A R010 00-05-01
# 10406968  N062A R010 00-06-01 1546290000.0  N062A R010 00-06-01
# 10406969  N062A R010 00-00-05 1546290000.0  N062A R010 00-00-05
# 10406970  N062A R010 00-00-02 1546290000.0  N062A R010 00-00-02
# 10406971  N062A R010 00-05-00 1546290000.0  N062A R010 00-05-00
# 10406972  N062A R010 00-00-04 1546290000.0  N062A R010 00-00-04
# 10406973  N062A R010 00-00-03 1546290000.0  N062A R010 00-00-03
# 10406974  N062A R010 00-00-00 1546290000.0  N062A R010 00-00-00
# 10406975  N062A R010 00-06-00 1546290000.0  N062A R010 00-06-00
# 10406976  N062A R010 00-00-01 1546290000.0  N062A R010 00-00-01
# 10406977   N303 R015 00-00-02 1546290000.0   N303 R015 00-00-02
# 10406978   N303 R015 00-00-08 1546290000.0   N303 R015 00-00-08
# 10406979   N303 R015 00-00-0B 1546290000.0   N303 R015 00-00-0B
# 10406980   N303 R015 00-00-07 1546290000.0   N303 R015 00-00-07
# 10406981   N303 R015 00-00-03 1546290000.0   N303 R015 00-00-03
# 10406982   N303 R015 00-00-09 1546290000.0   N303 R015 00-00-09
# 10406983   N303 R015 00-00-01 1546290000.0   N303 R015 00-00-01
# 10406984   N303 R015 00-00-06 1546290000.0   N303 R015 00-00-06
#
#          remote_unit_id    time_stamp     station_name     entries  \
# 10406998           R293  1.546290e+09   34 ST-PENN STA      158353
# 10406999           R293  1.546290e+09   34 ST-PENN STA       53313
# 10407000           R293  1.546290e+09   34 ST-PENN STA     1569424
# 10407001           R293  1.546290e+09   34 ST-PENN STA    22123940
# 10407002           R293  1.546290e+09   34 ST-PENN STA     5076351
# 10407003           R293  1.546290e+09   34 ST-PENN STA     6895211
# 10407004           R293  1.546290e+09   34 ST-PENN STA     5889422
# 10407005           R293  1.546290e+09   34 ST-PENN STA    98405984
# 10407006           R293  1.546290e+09   34 ST-PENN STA      156894
# 10407007           R293  1.546290e+09   34 ST-PENN STA     1273222
# 10407008           R293  1.546290e+09   34 ST-PENN STA       39616
# 10407009           R293  1.546290e+09   34 ST-PENN STA      137386
# 10407010           R293  1.546290e+09   34 ST-PENN STA     9099108
# 10407011           R293  1.546290e+09   34 ST-PENN STA  1569224106
# 10407012           R293  1.546290e+09   34 ST-PENN STA     9257014
# 10407013           R293  1.546290e+09   34 ST-PENN STA    19104000
# 10407014           R293  1.546290e+09   34 ST-PENN STA     9656458
# 10407015           R293  1.546290e+09   34 ST-PENN STA   100808488
# 10407016           R293  1.546290e+09   34 ST-PENN STA    10408362
# 10407017           R293  1.546290e+09   34 ST-PENN STA    67790698
# 10407018           R293  1.546290e+09   34 ST-PENN STA     6693396
# 10407019           R293  1.546290e+09   34 ST-PENN STA      251451
# 10407020           R293  1.546290e+09   34 ST-PENN STA    12754931
# 10406958           R010  1.546290e+09  42 ST-PORT AUTH     3513150
# 10406959           R010  1.546290e+09  42 ST-PORT AUTH    14398190
# 10406960           R010  1.546290e+09  42 ST-PORT AUTH     3280939
# 10406961           R010  1.546290e+09  42 ST-PORT AUTH      700400
# 10406962           R010  1.546290e+09  42 ST-PORT AUTH    10760348
# 10406963           R010  1.546290e+09  42 ST-PORT AUTH    16146835
# 10406964           R010  1.546290e+09  42 ST-PORT AUTH    50334011
# 10406965           R010  1.546290e+09  42 ST-PORT AUTH     4622425
# 10406966           R010  1.546290e+09  42 ST-PORT AUTH           0
# 10406967           R010  1.546290e+09  42 ST-PORT AUTH    20203629
# 10406968           R010  1.546290e+09  42 ST-PORT AUTH   104353767
# 10406969           R010  1.546290e+09  42 ST-PORT AUTH    16221630
# 10406970           R010  1.546290e+09  42 ST-PORT AUTH     4172135
# 10406971           R010  1.546290e+09  42 ST-PORT AUTH    68821217
# 10406972           R010  1.546290e+09  42 ST-PORT AUTH     9578846
# 10406973           R010  1.546290e+09  42 ST-PORT AUTH     9246086
# 10406974           R010  1.546290e+09  42 ST-PORT AUTH     7514422
# 10406975           R010  1.546290e+09  42 ST-PORT AUTH     5089072
# 10406976           R010  1.546290e+09  42 ST-PORT AUTH     6982653
# 10406977           R015  1.546290e+09       5 AV/53 ST     1563516
# 10406978           R015  1.546290e+09       5 AV/53 ST     6056253
# 10406979           R015  1.546290e+09       5 AV/53 ST     1736688
# 10406980           R015  1.546290e+09       5 AV/53 ST     2839468
# 10406981           R015  1.546290e+09       5 AV/53 ST     7666113
# 10406982           R015  1.546290e+09       5 AV/53 ST      905145
# 10406983           R015  1.546290e+09       5 AV/53 ST    13724119
# 10406984           R015  1.546290e+09       5 AV/53 ST     2706577
#
#                exits description
# 10406998      233074     REGULAR
# 10406999       59850     REGULAR
# 10407000      974507     REGULAR
# 10407001    11841883     REGULAR
# 10407002     6276942     REGULAR
# 10407003     5302078     REGULAR
# 10407004     2033752     REGULAR
# 10407005  1155428577     REGULAR
# 10407006      139918     REGULAR
# 10407007      699949     REGULAR
# 10407008       23007     REGULAR
# 10407009      241648     REGULAR
# 10407010     5301031     REGULAR
# 10407011  1129133869     REGULAR
# 10407012     5144392     REGULAR
# 10407013     9112315     REGULAR
# 10407014     4703888     REGULAR
# 10407015      875754     REGULAR
# 10407016     8127506     REGULAR
# 10407017    18181857     REGULAR
# 10407018     5827413     REGULAR
# 10407019      720318     REGULAR
# 10407020     8260453     REGULAR
# 10406958     1263651     REGULAR
# 10406959    12735832     REGULAR
# 10406960     3108571     REGULAR
# 10406961      900841     REGULAR
# 10406962    16558534     REGULAR
# 10406963    15322691     REGULAR
# 10406964    16777216     REGULAR
# 10406965     2559571     REGULAR
# 10406966         498     REGULAR
# 10406967     3910529     REGULAR
# 10406968     4263125     REGULAR
# 10406969     8601308     REGULAR
# 10406970     2287937     REGULAR
# 10406971    19045179     REGULAR
# 10406972     5457229     REGULAR
# 10406973     4897355     REGULAR
# 10406974     1732980     REGULAR
# 10406975     5705141     REGULAR
# 10406976     2854654     REGULAR
# 10406977      789240     REGULAR
# 10406978     8797917     REGULAR
# 10406979     2457074     REGULAR
# 10406980     2359604     REGULAR
# 10406981     5486692     REGULAR
# 10406982     1419187     REGULAR
# 10406983    10823792     REGULAR
# 10406984     1062223     REGULAR
